# %% [markdown]
# # Practice 5
#
# ## Constrained Optimization: Equality and Inequality Constraints
#
# ### This laboratory focuses on constrained optimization for the case in which equality and inequality constraints may appear in the support vector machines.
#
# ---
#
# ### 1. Problem statement
#
# ESCRIBIM ACÍ EL PLANTEJAMENT DEL PROBLEMA !!!

# %% [markdown]
# ### 2. Experiments
#
# In order to do this exercise, implementation of the minimization of (9) is provide. The function is called as QPGenericConstraints.
#
#  - **Experiment 1**.

# %%
import numpy as np

n=200; p=3; m=400
G=np.zeros((n,n))
g=np.zeros(n)
A=np.zeros((n,p))
b=np.zeros(p)
C=np.zeros((n,m))
d=np.zeros(m)

print(G.shape)
print(A.shape)
print(C.shape)
print(g.shape)
print(d.shape)
print(b.shape)
